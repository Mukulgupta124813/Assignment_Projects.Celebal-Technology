# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 5.0 MB/s eta 0:00:00
# ...

# %%
curl -L "https://app.roboflow.com/ds/0FyjxEsVCj?key=DQZpnU6zlO" &gt; roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.138, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to HoleInRoads-2 in yolov8:: 100%|██████████| 470/470 [00:00<00:00, 2218.10it/s]

# %%
# !git clone https://github.com/ultralytics/ultralytics
# !cd ultralytics
# !pip install -e ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 12718, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 12718 (delta 24), reused 45 (delta 16), pack-reused 12661
# Receiving objects: 100% (12718/12718), 7.49 MiB | 13.94 MiB/s, done.
# Resolving deltas: 100% (8570/8570), done.
# Obtaining file:///content/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.138
#     Uninstalling ultralytics-8.0.138:
#       Successfully uninstalled ultralytics-8.0.138
#   Running setup.py develop for ultralytics
# ...

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=/content/HoleInRoads-2/data.yaml \
epochs=25 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/runs/detect/train/weights/best.pt \
data=/content/HoleInRoads-2/data.yaml
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
# val: Scanning /content/HoleInRoads-2/valid/labels.cache... 50 images, 0 backgrounds, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:46<00:00, 11.55s/it]
#                    all         50        128      0.235       0.18      0.126     0.0546
# Speed: 7.8ms preprocess, 890.6ms inference, 0.0ms loss, 7.3ms postprocess per image
# Results saved to runs/detect/val2

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train/weights/best.pt \
conf=0.25 \
source= HoleInRoads-2/test/images
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/100 /content/HoleInRoads-2/test/images/0166_jpg.rf.f160f49b839d4f3e2df6c914e69caa93.jpg: 640x640 1 0, 663.4ms
# image 2/100 /content/HoleInRoads-2/test/images/0187_jpg.rf.c40d65a7ae4dccba4dba257c4c1debe8.jpg: 640x640 1 0, 595.7ms
# image 3/100 /content/HoleInRoads-2/test/images/0208_jpg.rf.2646f29a7c5866b47d08194fb876cbf9.jpg: 640x640 1 0, 593.3ms
# image 4/100 /content/HoleInRoads-2/test/images/0238_jpg.rf.aac65f7c2baf3bd195e203c04298f24c.jpg: 640x640 1 0, 603.0ms
# image 5/100 /content/HoleInRoads-2/test/images/0294_jpg.rf.013369127871ee723e3139d71df49431.jpg: 640x640 (no detections), 600.6ms
# image 6/100 /content/HoleInRoads-2/test/images/0305_jpg.rf.a2f3677ab110660685d7702d219cea85.jpg: 640x640 3 0s, 603.2ms
# ...
